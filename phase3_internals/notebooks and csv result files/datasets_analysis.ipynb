# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from pathlib import Path

# %%
path = "/Users/tommasomilanino/Developer/THESIS/phase3_internals/dataset_building/prompt_pool.parquet"
data = pd.read_parquet(path)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25858 entries, 0 to 25857
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   prompt_id         25858 non-null  object
#  1   source_prompt_id  25858 non-null  object
#  2   text_native       25858 non-null  object
#  3   text_source       25858 non-null  object
#  4   language          25858 non-null  object
#  5   category          25858 non-null  object
#  6   source            25858 non-null  object
#  7   is_translated     25858 non-null  bool
# dtypes: bool(1), object(7)
# memory usage: 1.4+ MB

# %%
data["language"].value_counts()
# Out:
# language
# english    12246
# russian     5000
# arabic      4063
# german      2977
# french       809
# spanish      763
# Name: count, dtype: int64
